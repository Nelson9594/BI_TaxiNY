# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = '/Users/nelson/Desktop/BI_streamlit/data/caractéristiques.csv'

df = pd.read_csv(dataset, delimiter=';')

# %%
df
# Out:
#          idBank      Dernière mise à jour  \
# 0     001737244          30/03/2018 12:00
# 1     001737245          30/03/2018 12:00
# 2     001737246          30/03/2018 12:00
# 3     001737247          30/03/2018 12:00
# 4     001737248          30/03/2018 12:00
# ...         ...                       ...
# 1480          R                  Révision
# 1481          A            Valeur normale
# 1482          N  Valeur non significative
# 1483          O          Valeur manquante
# 1484          U           Valeur atypique
#
#                                Correction             Zone géographique  \
# 0     Corrigé des variations saisonnières                      01 - Ain
# 1     Corrigé des variations saisonnières                    02 - Aisne
# 2     Corrigé des variations saisonnières                   03 - Allier
# 3     Corrigé des variations saisonnières  04 - Alpes-de-Haute-Provence
# 4     Corrigé des variations saisonnières             05 - Hautes-Alpes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1485 entries, 0 to 1484
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   idBank                1483 non-null   object
#  1   Dernière mise à jour  1482 non-null   object
#  2   Correction            1472 non-null   object
#  3   Zone géographique     1472 non-null   object
#  4   Série arrêtée         1472 non-null   object
#  5   Nature                1472 non-null   object
#  6   Puissance             1472 non-null   float64
#  7   Activité              1472 non-null   object
#  8   Indicateur            1472 non-null   object
#  9   Unité                 1472 non-null   object
#  10  Périodicité           1472 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 127.7+ KB

# %%
df_dropna = df.dropna()
df_dropna
# Out:
#          idBank             Zone géographique Série arrêtée  \
# 0     001737244                      01 - Ain           oui
# 1     001737245                    02 - Aisne           oui
# 2     001737246                   03 - Allier           oui
# 3     001737247  04 - Alpes-de-Haute-Provence           oui
# 4     001737248             05 - Hautes-Alpes           oui
# ...         ...                           ...           ...
# 1467  010568041              974 - La Réunion           non
# 1468  010568020              971 - Guadeloupe           non
# 1469  010568021              972 - Martinique           non
# 1470  010568022                  973 - Guyane           non
# 1471  010568023              974 - La Réunion           non
#
#                                                Activité  \
# 0     A17-GZ - Commerce ; réparation d'automobiles e...
# 1     A17-GZ - Commerce ; réparation d'automobiles e...
# 2     A17-GZ - Commerce ; réparation d'automobiles e...
# ...

# %%
df_dropna.to_csv('/Users/nelson/Desktop/BI_streamlit/data/normDataset/caracteristique.csv', index=False)

# %%
df_new = pd.read_csv('/Users/nelson/Desktop/BI_streamlit/data/normDataset/caracteristique.csv', delimiter=',')
df_new
# Out:
#         idBank             Zone géographique Série arrêtée  \
# 0      1737244                      01 - Ain           oui
# 1      1737245                    02 - Aisne           oui
# 2      1737246                   03 - Allier           oui
# 3      1737247  04 - Alpes-de-Haute-Provence           oui
# 4      1737248             05 - Hautes-Alpes           oui
# ...        ...                           ...           ...
# 1467  10568041              974 - La Réunion           non
# 1468  10568020              971 - Guadeloupe           non
# 1469  10568021              972 - Martinique           non
# 1470  10568022                  973 - Guyane           non
# 1471  10568023              974 - La Réunion           non
#
#                                                Activité  \
# 0     A17-GZ - Commerce ; réparation d'automobiles e...
# 1     A17-GZ - Commerce ; réparation d'automobiles e...
# 2     A17-GZ - Commerce ; réparation d'automobiles e...
# ...
